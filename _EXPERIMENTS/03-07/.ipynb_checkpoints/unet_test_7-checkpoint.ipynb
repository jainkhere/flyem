# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os

# %%
# !pip install keras-unet
# Out:
# Requirement already satisfied: keras-unet in /home/kunal.jain001/miniconda3/envs/O/lib/python3.9/site-packages (0.1.2)

# %%
import keras
from keras_unet.models import custom_unet
# Out:
# 2023-03-06 14:02:41.243418: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /home/kunal.jain001/miniconda3/envs/O/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
DATAPATH = '/raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/npy_files'
images_file = os.path.join(DATAPATH, 'fly-mar-06-original-images.npy')
labels_file = os.path.join(DATAPATH, 'fly-mar-06-segmented.npy')

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
images.shape
# Out:
# (56, 512, 512)

# %%
# full dataset does not have the last channel
images = images.reshape(images.shape[0],images.shape[1],images.shape[2],1)
labels = labels.reshape(labels.shape[0],labels.shape[1],labels.shape[2],1)

# %%
images.shape
# Out:
# (56, 512, 512, 1)

# %%
p = np.random.permutation(len(images))

# %%
images = images[p]
labels = labels[p]

# %%
labels = labels.astype(np.float64)

# %%
images = images.astype(np.float64)

for i in range(images.shape[0]):
    images[i] = (images[i] - images[i].min()) / (images[i].max() - images[i].min()) # normalize individually
    

    #
    # TODO: Use Tensorflow to flip the image horizontally
    #
    if tf.random.uniform(()) > 0.5:
        #
        # TODO: YOUR CODE
        #
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    #
    # TODO: Use Tensorflow to flip the image vertically
    #
    if tf.random.uniform(()) > 0.5:
        #
        # TODO: YOUR CODE
        #
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    #
    # TODO: Use Tensorflow to rotate the image 90 degrees
    #
    if tf.random.uniform(()) > 0.5:
        #
        # TODO: YOUR CODE
        #
        image = tf.image.rot90(image)
        mask = tf.image.rot90(mask)


    # augmentation done, let's store the image
    images[i] = image

# %%
images.shape
# Out:
# (56, 512, 512, 1)

# %%
X_train = images[0:40]
y_train = labels[0:40]
X_val = images[40:50]
y_val = labels[40:50]
X_test = images[50:]
y_test = labels[50:]

# %%
model = custom_unet(
    input_shape=(512, 512, 1),
    use_batch_norm=False,
    num_classes=1,
    filters=32,
    dropout=0.5,
    output_activation='sigmoid')
# Out:
# 2023-03-06 14:02:43.604903: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-03-06 14:02:43.634579: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-03-06 14:02:43.634600: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: chimera13
# 2023-03-06 14:02:43.634605: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: chimera13
# 2023-03-06 14:02:43.634670: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 450.172.1
# 2023-03-06 14:02:43.634684: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 450.172.1
# 2023-03-06 14:02:43.634689: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 450.172.1
# 2023-03-06 14:02:43.635187: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import keras.optimizers
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance

# %%
opt = keras.optimizer_v1.Adam(lr=0.01)

# %%
model.compile(optimizer = 'Adam',    
              loss='binary_crossentropy', 
              metrics=[iou, iou_thresholded])

# %%
history = model.fit(X_train, 
                    y_train, 
                    32, 
                    epochs=100,
                    validation_data=(X_val, y_val), 
                    verbose=1)
# Out:
# 2023-03-06 14:02:44.336199: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-03-06 14:02:44.337421: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245645000 Hz
# Epoch 1/100
# 2/2 [==============================] - 231s 57s/step - loss: 0.6849 - iou: 0.0560 - iou_thresholded: 0.0449 - val_loss: 0.5563 - val_iou: 0.0814 - val_iou_thresholded: 7.2057e-06
# Epoch 2/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.5179 - iou: 0.0774 - iou_thresholded: 0.0016 - val_loss: 0.5136 - val_iou: 0.0745 - val_iou_thresholded: 3.6177e-06
# Epoch 3/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4754 - iou: 0.0654 - iou_thresholded: 2.3533e-06 - val_loss: 0.4524 - val_iou: 0.0604 - val_iou_thresholded: 3.6179e-06
# Epoch 4/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4423 - iou: 0.0506 - iou_thresholded: 7.6224e-04 - val_loss: 0.4191 - val_iou: 0.0446 - val_iou_thresholded: 3.6179e-06
# Epoch 5/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4356 - iou: 0.0363 - iou_thresholded: 2.9414e-06 - val_loss: 0.4133 - val_iou: 0.0369 - val_iou_thresholded: 3.6179e-06
# Epoch 6/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4621 - iou: 0.0263 - iou_thresholded: 2.8371e-06 - val_loss: 0.4147 - val_iou: 0.0440 - val_iou_thresholded: 3.6179e-06
# Epoch 7/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4427 - iou: 0.0375 - iou_thresholded: 2.7074e-06 - val_loss: 0.4276 - val_iou: 0.0538 - val_iou_thresholded: 3.6179e-06
# Epoch 8/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4283 - iou: 0.0433 - iou_thresholded: 2.7380e-06 - val_loss: 0.4445 - val_iou: 0.0615 - val_iou_thresholded: 3.6179e-06
# Epoch 9/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4276 - iou: 0.0492 - iou_thresholded: 2.8273e-06 - val_loss: 0.4517 - val_iou: 0.0649 - val_iou_thresholded: 3.6179e-06
# Epoch 10/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4266 - iou: 0.0477 - iou_thresholded: 2.7083e-06 - val_loss: 0.4465 - val_iou: 0.0648 - val_iou_thresholded: 3.6179e-06
# Epoch 11/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4166 - iou: 0.0428 - iou_thresholded: 2.5655e-06 - val_loss: 0.4385 - val_iou: 0.0643 - val_iou_thresholded: 3.6179e-06
# Epoch 12/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4130 - iou: 0.0443 - iou_thresholded: 2.5485e-06 - val_loss: 0.4354 - val_iou: 0.0653 - val_iou_thresholded: 3.6179e-06
# Epoch 13/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4128 - iou: 0.0446 - iou_thresholded: 2.6674e-06 - val_loss: 0.4451 - val_iou: 0.0687 - val_iou_thresholded: 3.6179e-06
# Epoch 14/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.4090 - iou: 0.0425 - iou_thresholded: 2.6919e-06 - val_loss: 0.4497 - val_iou: 0.0717 - val_iou_thresholded: 3.6179e-06
# Epoch 15/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4062 - iou: 0.0451 - iou_thresholded: 2.7575e-06 - val_loss: 0.4748 - val_iou: 0.0765 - val_iou_thresholded: 3.6179e-06
# Epoch 16/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4047 - iou: 0.0514 - iou_thresholded: 2.6065e-06 - val_loss: 0.4395 - val_iou: 0.0750 - val_iou_thresholded: 3.6179e-06
# Epoch 17/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4230 - iou: 0.0482 - iou_thresholded: 2.5597e-06 - val_loss: 0.5091 - val_iou: 0.0824 - val_iou_thresholded: 3.6179e-06
# Epoch 18/100
# 2/2 [==============================] - 228s 56s/step - loss: 0.4312 - iou: 0.0680 - iou_thresholded: 2.5084e-06 - val_loss: 0.4990 - val_iou: 0.0822 - val_iou_thresholded: 3.6179e-06
# Epoch 19/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4185 - iou: 0.0596 - iou_thresholded: 2.6787e-06 - val_loss: 0.4554 - val_iou: 0.0782 - val_iou_thresholded: 3.6179e-06
# Epoch 20/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4036 - iou: 0.0463 - iou_thresholded: 3.2003e-06 - val_loss: 0.3997 - val_iou: 0.0685 - val_iou_thresholded: 3.6179e-06
# Epoch 21/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4070 - iou: 0.0387 - iou_thresholded: 2.7206e-06 - val_loss: 0.3891 - val_iou: 0.0671 - val_iou_thresholded: 3.6179e-06
# Epoch 22/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4081 - iou: 0.0381 - iou_thresholded: 2.6207e-06 - val_loss: 0.4198 - val_iou: 0.0758 - val_iou_thresholded: 3.6179e-06
# Epoch 23/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3971 - iou: 0.0468 - iou_thresholded: 2.8894e-06 - val_loss: 0.4553 - val_iou: 0.0811 - val_iou_thresholded: 3.6179e-06
# Epoch 24/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3986 - iou: 0.0564 - iou_thresholded: 2.8817e-06 - val_loss: 0.4601 - val_iou: 0.0823 - val_iou_thresholded: 3.6179e-06
# Epoch 25/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.4001 - iou: 0.0632 - iou_thresholded: 2.4674e-06 - val_loss: 0.4371 - val_iou: 0.0812 - val_iou_thresholded: 3.6179e-06
# Epoch 26/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3897 - iou: 0.0537 - iou_thresholded: 2.6187e-06 - val_loss: 0.4027 - val_iou: 0.0785 - val_iou_thresholded: 3.6179e-06
# Epoch 27/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3911 - iou: 0.0392 - iou_thresholded: 2.9054e-06 - val_loss: 0.3894 - val_iou: 0.0786 - val_iou_thresholded: 3.6179e-06
# Epoch 28/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.3878 - iou: 0.0471 - iou_thresholded: 2.6116e-06 - val_loss: 0.4018 - val_iou: 0.0823 - val_iou_thresholded: 3.6179e-06
# Epoch 29/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3789 - iou: 0.0492 - iou_thresholded: 2.9724e-06 - val_loss: 0.4194 - val_iou: 0.0857 - val_iou_thresholded: 3.6179e-06
# Epoch 30/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.3758 - iou: 0.0608 - iou_thresholded: 2.6787e-06 - val_loss: 0.4110 - val_iou: 0.0880 - val_iou_thresholded: 3.6179e-06
# Epoch 31/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3737 - iou: 0.0618 - iou_thresholded: 2.5645e-06 - val_loss: 0.3785 - val_iou: 0.0895 - val_iou_thresholded: 3.6179e-06
# Epoch 32/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.3722 - iou: 0.0519 - iou_thresholded: 3.0022e-06 - val_loss: 0.3581 - val_iou: 0.0911 - val_iou_thresholded: 3.6179e-06
# Epoch 33/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3700 - iou: 0.0510 - iou_thresholded: 2.4944e-06 - val_loss: 0.3758 - val_iou: 0.0953 - val_iou_thresholded: 3.6179e-06
# Epoch 34/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3611 - iou: 0.0632 - iou_thresholded: 2.7470e-06 - val_loss: 0.4054 - val_iou: 0.0977 - val_iou_thresholded: 3.6179e-06
# Epoch 35/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3602 - iou: 0.0722 - iou_thresholded: 2.6644e-06 - val_loss: 0.3892 - val_iou: 0.1010 - val_iou_thresholded: 3.6179e-06
# Epoch 36/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.3506 - iou: 0.0740 - iou_thresholded: 2.8076e-06 - val_loss: 0.3248 - val_iou: 0.1036 - val_iou_thresholded: 3.6179e-06
# Epoch 37/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.3475 - iou: 0.0612 - iou_thresholded: 2.7835e-06 - val_loss: 0.2947 - val_iou: 0.1051 - val_iou_thresholded: 3.6179e-06
# Epoch 38/100
# 2/2 [==============================] - 229s 57s/step - loss: 0.3676 - iou: 0.0623 - iou_thresholded: 2.7336e-06 - val_loss: 0.3438 - val_iou: 0.1120 - val_iou_thresholded: 3.6179e-06
# Epoch 39/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3325 - iou: 0.0805 - iou_thresholded: 2.6610e-06 - val_loss: 0.3843 - val_iou: 0.1106 - val_iou_thresholded: 3.6179e-06
# Epoch 40/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3533 - iou: 0.0895 - iou_thresholded: 2.7740e-06 - val_loss: 0.3460 - val_iou: 0.1169 - val_iou_thresholded: 3.6179e-06
# Epoch 41/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3364 - iou: 0.0768 - iou_thresholded: 2.6483e-06 - val_loss: 0.2898 - val_iou: 0.1248 - val_iou_thresholded: 3.6179e-06
# Epoch 42/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3113 - iou: 0.0832 - iou_thresholded: 2.8155e-06 - val_loss: 0.2713 - val_iou: 0.1308 - val_iou_thresholded: 3.6179e-06
# Epoch 43/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3435 - iou: 0.0866 - iou_thresholded: 2.7957e-06 - val_loss: 0.3011 - val_iou: 0.1308 - val_iou_thresholded: 3.6179e-06
# Epoch 44/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3249 - iou: 0.0857 - iou_thresholded: 2.8841e-06 - val_loss: 0.3022 - val_iou: 0.1317 - val_iou_thresholded: 3.6179e-06
# Epoch 45/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3051 - iou: 0.0986 - iou_thresholded: 2.9143e-06 - val_loss: 0.2726 - val_iou: 0.1366 - val_iou_thresholded: 3.6179e-06
# Epoch 46/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.2992 - iou: 0.0937 - iou_thresholded: 2.8207e-06 - val_loss: 0.2571 - val_iou: 0.1397 - val_iou_thresholded: 3.6179e-06
# Epoch 47/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3079 - iou: 0.0900 - iou_thresholded: 2.7760e-06 - val_loss: 0.2564 - val_iou: 0.1445 - val_iou_thresholded: 3.6179e-06
# Epoch 48/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.2913 - iou: 0.1036 - iou_thresholded: 2.7492e-06 - val_loss: 0.2633 - val_iou: 0.1478 - val_iou_thresholded: 3.6179e-06
# Epoch 49/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.2744 - iou: 0.1162 - iou_thresholded: 2.8890e-06 - val_loss: 0.2624 - val_iou: 0.1518 - val_iou_thresholded: 3.6179e-06
# Epoch 50/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.3030 - iou: 0.1164 - iou_thresholded: 2.6662e-06 - val_loss: 0.2266 - val_iou: 0.1606 - val_iou_thresholded: 3.6179e-06
# Epoch 51/100
# 2/2 [==============================] - 228s 57s/step - loss: 0.2946 - iou: 0.1170 - iou_thresholded: 2.5710e-06 - val_loss: 0.2228 - val_iou: 0.1645 - val_iou_thresholded: 3.6179e-06
# Epoch 52/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2887 - iou: 0.1230 - iou_thresholded: 2.4255e-06 - val_loss: 0.2723 - val_iou: 0.1597 - val_iou_thresholded: 3.6179e-06
# Epoch 53/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2907 - iou: 0.1317 - iou_thresholded: 3.6011e-04 - val_loss: 0.2541 - val_iou: 0.1628 - val_iou_thresholded: 3.6179e-06
# Epoch 54/100
# 2/2 [==============================] - 227s 57s/step - loss: 0.2856 - iou: 0.1327 - iou_thresholded: 2.8146e-06 - val_loss: 0.2477 - val_iou: 0.1625 - val_iou_thresholded: 3.6179e-06
# Epoch 55/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2588 - iou: 0.1448 - iou_thresholded: 2.7076e-06 - val_loss: 0.2195 - val_iou: 0.1657 - val_iou_thresholded: 3.6179e-06
# Epoch 56/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2717 - iou: 0.1311 - iou_thresholded: 2.6511e-06 - val_loss: 0.2067 - val_iou: 0.1686 - val_iou_thresholded: 3.6179e-06
# Epoch 57/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2695 - iou: 0.1449 - iou_thresholded: 2.4518e-06 - val_loss: 0.1969 - val_iou: 0.2011 - val_iou_thresholded: 3.6179e-06
# Epoch 58/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2448 - iou: 0.1615 - iou_thresholded: 0.0144 - val_loss: 0.2038 - val_iou: 0.1808 - val_iou_thresholded: 3.6179e-06
# Epoch 59/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2828 - iou: 0.1384 - iou_thresholded: 2.6106e-06 - val_loss: 0.1907 - val_iou: 0.2087 - val_iou_thresholded: 3.6179e-06
# Epoch 60/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2628 - iou: 0.1524 - iou_thresholded: 4.3185e-05 - val_loss: 0.2219 - val_iou: 0.1998 - val_iou_thresholded: 3.6179e-06
# Epoch 61/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2711 - iou: 0.1637 - iou_thresholded: 6.8494e-04 - val_loss: 0.1922 - val_iou: 0.2058 - val_iou_thresholded: 3.6179e-06
# Epoch 62/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2297 - iou: 0.1774 - iou_thresholded: 1.8425e-05 - val_loss: 0.1947 - val_iou: 0.1907 - val_iou_thresholded: 3.6179e-06
# Epoch 63/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2705 - iou: 0.1378 - iou_thresholded: 2.4599e-06 - val_loss: 0.2027 - val_iou: 0.2133 - val_iou_thresholded: 3.6179e-06
# Epoch 64/100
# 2/2 [==============================] - 227s 57s/step - loss: 0.2564 - iou: 0.1682 - iou_thresholded: 0.0035 - val_loss: 0.2694 - val_iou: 0.1836 - val_iou_thresholded: 3.9797e-05
# Epoch 65/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.3010 - iou: 0.1623 - iou_thresholded: 0.0125 - val_loss: 0.2385 - val_iou: 0.1989 - val_iou_thresholded: 3.4732e-04
# Epoch 66/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2725 - iou: 0.1755 - iou_thresholded: 0.0115 - val_loss: 0.1858 - val_iou: 0.2222 - val_iou_thresholded: 3.6179e-06
# Epoch 67/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2260 - iou: 0.1818 - iou_thresholded: 0.0043 - val_loss: 0.1696 - val_iou: 0.2482 - val_iou_thresholded: 0.0153
# Epoch 68/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.2498 - iou: 0.2168 - iou_thresholded: 0.0976 - val_loss: 0.3043 - val_iou: 0.2166 - val_iou_thresholded: 0.3213
# Epoch 69/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.3377 - iou: 0.2149 - iou_thresholded: 0.1867 - val_loss: 0.1711 - val_iou: 0.2438 - val_iou_thresholded: 6.3313e-04
# Epoch 70/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2371 - iou: 0.1740 - iou_thresholded: 0.0034 - val_loss: 0.1825 - val_iou: 0.2189 - val_iou_thresholded: 3.6179e-06
# Epoch 71/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2201 - iou: 0.1727 - iou_thresholded: 3.1715e-06 - val_loss: 0.1845 - val_iou: 0.2200 - val_iou_thresholded: 3.6179e-06
# Epoch 72/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2274 - iou: 0.1901 - iou_thresholded: 3.1934e-06 - val_loss: 0.1725 - val_iou: 0.2385 - val_iou_thresholded: 3.6179e-06
# Epoch 73/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2258 - iou: 0.1981 - iou_thresholded: 2.7010e-04 - val_loss: 0.1612 - val_iou: 0.2646 - val_iou_thresholded: 5.4269e-05
# Epoch 74/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2065 - iou: 0.2258 - iou_thresholded: 0.0013 - val_loss: 0.1412 - val_iou: 0.3089 - val_iou_thresholded: 0.0168
# Epoch 75/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1779 - iou: 0.2670 - iou_thresholded: 0.1049 - val_loss: 0.1442 - val_iou: 0.3321 - val_iou_thresholded: 0.0800
# Epoch 76/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2199 - iou: 0.2626 - iou_thresholded: 0.1457 - val_loss: 0.1324 - val_iou: 0.3460 - val_iou_thresholded: 0.3689
# Epoch 77/100
# 2/2 [==============================] - 226s 57s/step - loss: 0.1848 - iou: 0.2931 - iou_thresholded: 0.3857 - val_loss: 0.1222 - val_iou: 0.3866 - val_iou_thresholded: 0.5149
# Epoch 78/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.1605 - iou: 0.3579 - iou_thresholded: 0.5070 - val_loss: 0.1130 - val_iou: 0.4750 - val_iou_thresholded: 0.6426
# Epoch 79/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.2034 - iou: 0.3556 - iou_thresholded: 0.4532 - val_loss: 0.1154 - val_iou: 0.4543 - val_iou_thresholded: 0.6250
# Epoch 80/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1584 - iou: 0.3503 - iou_thresholded: 0.4368 - val_loss: 0.1261 - val_iou: 0.3627 - val_iou_thresholded: 0.5317
# Epoch 81/100
# 2/2 [==============================] - 226s 57s/step - loss: 0.1697 - iou: 0.2978 - iou_thresholded: 0.4703 - val_loss: 0.1491 - val_iou: 0.3116 - val_iou_thresholded: 0.5637
# Epoch 82/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1926 - iou: 0.2592 - iou_thresholded: 0.3591 - val_loss: 0.1319 - val_iou: 0.3368 - val_iou_thresholded: 0.3086
# Epoch 83/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1838 - iou: 0.2451 - iou_thresholded: 0.1863 - val_loss: 0.1309 - val_iou: 0.3471 - val_iou_thresholded: 0.3542
# Epoch 84/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1840 - iou: 0.2801 - iou_thresholded: 0.2805 - val_loss: 0.1540 - val_iou: 0.3170 - val_iou_thresholded: 0.5890
# Epoch 85/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1863 - iou: 0.2870 - iou_thresholded: 0.4887 - val_loss: 0.1683 - val_iou: 0.3113 - val_iou_thresholded: 0.5881
# Epoch 86/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.1820 - iou: 0.2791 - iou_thresholded: 0.4806 - val_loss: 0.1211 - val_iou: 0.3921 - val_iou_thresholded: 0.6073
# Epoch 87/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1665 - iou: 0.3436 - iou_thresholded: 0.4677 - val_loss: 0.1176 - val_iou: 0.4161 - val_iou_thresholded: 0.6001
# Epoch 88/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.1582 - iou: 0.3978 - iou_thresholded: 0.5222 - val_loss: 0.1216 - val_iou: 0.4537 - val_iou_thresholded: 0.6440
# Epoch 89/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.1458 - iou: 0.4240 - iou_thresholded: 0.6206 - val_loss: 0.1120 - val_iou: 0.4898 - val_iou_thresholded: 0.6609
# Epoch 90/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1242 - iou: 0.4704 - iou_thresholded: 0.6157 - val_loss: 0.1040 - val_iou: 0.5174 - val_iou_thresholded: 0.6628
# Epoch 91/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1444 - iou: 0.4382 - iou_thresholded: 0.5595 - val_loss: 0.1277 - val_iou: 0.5374 - val_iou_thresholded: 0.6602
# Epoch 92/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1482 - iou: 0.4696 - iou_thresholded: 0.6287 - val_loss: 0.1051 - val_iou: 0.5139 - val_iou_thresholded: 0.6656
# Epoch 93/100
# 2/2 [==============================] - 226s 57s/step - loss: 0.1307 - iou: 0.4411 - iou_thresholded: 0.6058 - val_loss: 0.1068 - val_iou: 0.4846 - val_iou_thresholded: 0.6227
# Epoch 94/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1300 - iou: 0.4447 - iou_thresholded: 0.5581 - val_loss: 0.1124 - val_iou: 0.5156 - val_iou_thresholded: 0.6604
# Epoch 95/100
# 2/2 [==============================] - 226s 57s/step - loss: 0.1244 - iou: 0.4783 - iou_thresholded: 0.6492 - val_loss: 0.1098 - val_iou: 0.5323 - val_iou_thresholded: 0.6673
# Epoch 96/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1161 - iou: 0.4928 - iou_thresholded: 0.6422 - val_loss: 0.1086 - val_iou: 0.5008 - val_iou_thresholded: 0.6256
# Epoch 97/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1323 - iou: 0.4700 - iou_thresholded: 0.6052 - val_loss: 0.1015 - val_iou: 0.5222 - val_iou_thresholded: 0.6643
# Epoch 98/100
# 2/2 [==============================] - 227s 56s/step - loss: 0.1180 - iou: 0.5076 - iou_thresholded: 0.6606 - val_loss: 0.1093 - val_iou: 0.5461 - val_iou_thresholded: 0.6787
# Epoch 99/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1315 - iou: 0.5187 - iou_thresholded: 0.6451 - val_loss: 0.1027 - val_iou: 0.4901 - val_iou_thresholded: 0.6316
# Epoch 100/100
# 2/2 [==============================] - 226s 56s/step - loss: 0.1228 - iou: 0.4458 - iou_thresholded: 0.5745 - val_loss: 0.1088 - val_iou: 0.4383 - val_iou_thresholded: 0.5920

# %%
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
y_pred = model.predict(X_test)

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=10)
