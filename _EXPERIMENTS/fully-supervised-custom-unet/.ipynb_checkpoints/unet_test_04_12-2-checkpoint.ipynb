# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from imports import *

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import data_management
from data_management import load_stack
from data_management import load_data

import interactive_plot

import metrics
from metrics import statistics
from metrics import confusion_matrix
from metrics import error_distribution
from metrics import error_borders
from metrics import PR_curve

import generator_extended

import unet
from unet import load_model_unet
from unet import predict_net
from unet import get_unet
from unet import train
from unet import execute_predict

# %%
NPYPATH = '/raid/mpsych/RISTERLAB/fly_segmentation_experiments/data_dir/test2/pre_processing/npy/'
MODELPATH = '/raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/models/04-12/'
PRED_TESTING_PATH = '/raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/models/04-12/predictions/'
images_file = os.path.join(NPYPATH, 'original.npy')
labels_file = os.path.join(NPYPATH, 'mask.npy')

# %%
def get_random_images_and_labels(images, labels, num_imgs = 10):
    random_indices = np.random.choice(len(images), num_imgs)
    
    print(random_indices)
    
    images = np.expand_dims(images, axis=3)
    labels = np.expand_dims(labels, axis=3)

    new_imgs = np.empty([num_imgs, 512, 512, 1])
    new_labels = np.empty([num_imgs, 512, 512, 1])
    z = 0
    for i in random_indices:
        new_imgs[z] = images[i]
        new_labels[z] = labels[i]
        z = z + 1
    return new_imgs, new_labels

# %%
images = np.load(images_file)
labels = np.load(labels_file)

# %%
model_path = os.path.join(MODELPATH, 'weights.84-0.04.hdf5')

# %%
model = load_model_unet(model_path, use_dice_loss=False, use_jaccard_loss=False, use_focal_loss=False)
# Out:
# 2023-04-12 12:04:33.941813: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-04-12 12:04:34.079308: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-12 12:04:34.082151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-12 12:04:34.082175: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-12 12:04:34.085650: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-04-12 12:04:34.085688: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-04-12 12:04:34.086598: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-04-12 12:04:34.086943: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-04-12 12:04:34.087502: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-04-12 12:04:34.088324: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-04-12 12:04:34.088582: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-04-12 12:04:34.099087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2023-04-12 12:04:34.099879: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-12 12:04:34.340798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-12 12:04:34.343383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 1 with properties:
# pciBusID: 0000:90:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-04-12 12:04:34.353276: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0, 1
# 2023-04-12 12:04:34.353337: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-12 12:04:35.069047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-04-12 12:04:35.069098: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0 1
# 2023-04-12 12:04:35.069105: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N Y
# 2023-04-12 12:04:35.069109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 1:   Y N
# 2023-04-12 12:04:35.081913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0)
# 2023-04-12 12:04:35.084859: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 38425 MB memory) -> physical GPU (device: 1, name: A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 512, 512, 32) 320         input_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 512, 512, 32) 0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 512, 512, 32) 9248        spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 256, 256, 32) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 64) 18496       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 256, 256, 64) 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 64) 36928       spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_12 (SpatialDr (None, 128, 128, 128 0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 128 147584      spatial_dropout2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 128)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_13 (SpatialDr (None, 64, 64, 256)  0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 64, 256)  590080      spatial_dropout2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 256)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 512)  1180160     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_14 (SpatialDr (None, 32, 32, 512)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 512)  2359808     spatial_dropout2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_8[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_9[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 128, 128, 128 295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 128, 128, 128 147584      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 256, 256, 64) 32832       conv2d_51[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 256, 256, 128 0           conv2d_transpose_10[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 512, 512, 32) 8224        conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 512, 512, 64) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 512, 512, 1)  33          conv2d_55[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_img, gt = get_random_images_and_labels(images, labels, num_imgs=1)
# Out:
# [813]

# %%
input_img = np.squeeze(input_img, axis=(0,))
gt = np.squeeze(gt, axis=(0,))

# %%
plt.figure(figsize = (15,15))
plt.imshow(input_img, cmap='gray')

print(input_img.shape)
res = execute_predict(model, input_img.reshape(1,512,512,1).astype(float)/255.)
print(res.min(), res.max())

if (res.max() > 0.5):    
    random_string = ''.join(random.choices(string.ascii_uppercase + string.digits, k=7))
    testing_path = PRED_TESTING_PATH + random_string + '/'

    if not os.path.isdir(testing_path):
        os.mkdir(testing_path)
    print('saving images at ' + testing_path)

    res[res>0.5]=1
    res[res<=0.5]=0

    plt.figure(figsize = (15,15))
    plt.imshow(res[0,:,:,0], cmap='gray')

    plt.figure(figsize = (15,15))
    plt.imshow(gt[:,:,0], cmap='gray')

    cv2.imwrite(os.path.join(testing_path, 'example_img_raw.png'), input_img)
    cv2.imwrite(os.path.join(testing_path, 'example_img_gt.png'), gt[:,:,0]*255)
    cv2.imwrite(os.path.join(testing_path, 'example_img.png'), res[0,:,:,0]*255.)
else:
    print("Not a good segmentation result :(")
# Out:
# (512, 512, 1)
# 1.9548744e-12 0.9962541
# saving images at /raid/mpsych/RISTERLAB/fly_segmentation_experiments/classified_images/models/04-12/predictions/SFZXNGC/
